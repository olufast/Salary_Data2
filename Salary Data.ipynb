# %% [markdown]
# Import Numpy as np
# Import Panda as pd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# Import Data

# %%
salaries = pd.read_csv('Salary_Data.csv')

# %% [markdown]
# Check the Head of the Data Frame

# %%
salaries.head()
# Out:
#    Age  Gender     Education Level          Job Title  Years of Experience  \
# 0   32    Male  Barchelor's Degree  Software Engineer                  5.0
# 1   28  Female     Master's Degree       Data Analyst                  3.0
# 2   45    Male                 PhD     Senior Manager                 15.0
# 3   36  Female  Barchelor's Degree    Sales Associate                  7.0
# 4   52    Male     Master's Degree           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %% [markdown]
# Number of Entries in the Data

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6702 entries, 0 to 6701
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6702 non-null   int64
#  1   Gender               6702 non-null   object
#  2   Education Level      6701 non-null   object
#  3   Job Title            6702 non-null   object
#  4   Years of Experience  6701 non-null   float64
#  5   Salary               6699 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 314.3+ KB

# %% [markdown]
# Eliminating Incomplete Data Set

# %%
salaries = salaries.dropna()

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6698 entries, 0 to 6701
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6698 non-null   int64
#  1   Gender               6698 non-null   object
#  2   Education Level      6698 non-null   object
#  3   Job Title            6698 non-null   object
#  4   Years of Experience  6698 non-null   float64
#  5   Salary               6698 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 366.3+ KB

# %% [markdown]
# Average Salary Given to Each Staff

# %%
salaries['Salary'].mean()
# Out:
# 115329.25306061511

# %% [markdown]
# Minimum Salary Earned

# %%
salaries['Salary'].min()
# Out:
# 350.0

# %% [markdown]
# Details of Lowest Paid Person

# %%
salaries[salaries['Salary'] == salaries['Salary'].min()]
# Out:
#      Age Gender     Education Level                           Job Title  \
# 258   29   Male  Barchelor's Degree  Junior Business Operations Analyst
#
#      Years of Experience  Salary
# 258                  1.5   350.0

# %% [markdown]
# Maximum Salary Earned.

# %%
salaries['Salary'].max()
# Out:
# 250000.0

# %% [markdown]
# Details of Highest Paid Person

# %%
salaries[salaries['Salary'] == salaries['Salary'].max()]
# Out:
#       Age Gender     Education Level                 Job Title  \
# 30     50   Male  Barchelor's Degree                       CEO
# 83     52   Male                 PhD  Chief Technology Officer
# 4999   45   Male  Barchelor's Degree         Financial Manager
#
#       Years of Experience    Salary
# 30                   25.0  250000.0
# 83                   24.0  250000.0
# 4999                 21.0  250000.0

# %% [markdown]
# No of People Employed by Gender

# %% [markdown]
# No of Male Employed

# %%
Males = salaries[salaries['Gender'] == 'Male']

# %%
Males
# Out:
#       Age Gender     Education Level                    Job Title  \
# 0      32   Male  Barchelor's Degree            Software Engineer
# 2      45   Male                 PhD               Senior Manager
# 4      52   Male     Master's Degree                     Director
# 5      29   Male  Barchelor's Degree            Marketing Analyst
# 7      31   Male  Barchelor's Degree                Sales Manager
# ...   ...    ...                 ...                          ...
# 6692   27   Male         High School    Digital Marketing Manager
# 6694   28   Male                 PhD         Sales Representative
# 6696   37   Male  Barchelor's Degree  Junior Sales Representative
# 6698   32   Male         High School              Sales Associate
# 6700   46   Male     Master's Degree            Marketing Manager
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 2                    15.0  150000.0
# 4                    20.0  200000.0
# ...

# %% [markdown]
# No of Female Gender

# %%
Females = salaries[salaries['Gender'] == 'Female']

# %%
Females
# Out:
#       Age  Gender     Education Level                         Job Title  \
# 1      28  Female     Master's Degree                      Data Analyst
# 3      36  Female  Barchelor's Degree                   Sales Associate
# 6      42  Female     Master's Degree                   Product Manager
# 8      26  Female  Barchelor's Degree             Marketing Coordinator
# 11     48  Female  Barchelor's Degree                        HR Manager
# ...   ...     ...                 ...                               ...
# 6693   33  Female  Barchelor's Degree         Content Marketing Manager
# 6695   51  Female     Master's Degree  Senior Product Marketing Manager
# 6697   49  Female                 PhD             Director of Marketing
# 6699   30  Female  Barchelor's Degree                 Financial Manager
# 6701   26  Female         High School                   Sales Executive
#
#       Years of Experience    Salary
# 1                     3.0   65000.0
# ...

# %% [markdown]
# No of Undisclosed Gender

# %%
Other = salaries[salaries['Gender'] == 'Other']

# %%
Other
# Out:
#       Age Gender  Education Level                 Job Title  \
# 2376   53  Other      High School   Senior Project Engineer
# 2383   25  Other      High School       Full Stack Engineer
# 2404   37  Other  Master's Degree       Full Stack Engineer
# 2446   31  Other      High School        Back end Developer
# 2452   23  Other      High School       Front end Developer
# 2456   53  Other      High School   Senior Project Engineer
# 2463   25  Other      High School       Full Stack Engineer
# 2484   37  Other  Master's Degree       Full Stack Engineer
# 2526   31  Other      High School        Back end Developer
# 2532   23  Other      High School       Front end Developer
# 2552   54  Other      High School  Senior Software Engineer
# 2798   54  Other      High School  Senior Software Engineer
# 2917   54  Other      High School  Senior Software Engineer
# 3036   54  Other      High School  Senior Software Engineer
#
#       Years of Experience    Salary
# ...

# %% [markdown]
# Visual Representation of Gender Distribution

# %%
sns.countplot(x = "Gender", data = salaries)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# Highest Paid Salary by Gender

# %%
Max = salaries.groupby('Gender')['Salary'].max()

# %%
Max
# Out:
# Gender
# Female    220000.0
# Male      250000.0
# Other     166109.0
# Name: Salary, dtype: float64

# %% [markdown]
# Highest Paid Male Gender

# %%
High_Male = Males[Males['Salary'] == Males['Salary'].max()]

# %%
High_Male
# Out:
#       Age Gender     Education Level                 Job Title  \
# 30     50   Male  Barchelor's Degree                       CEO
# 83     52   Male                 PhD  Chief Technology Officer
# 4999   45   Male  Barchelor's Degree         Financial Manager
#
#       Years of Experience    Salary
# 30                   25.0  250000.0
# 83                   24.0  250000.0
# 4999                 21.0  250000.0

# %% [markdown]
# Highest Paid Female

# %%
Highest_Paid_Females = Females[Females['Salary'] == Females['Salary'].max()]

# %%
Highest_Paid_Females
# Out:
#       Age  Gender Education Level                 Job Title  \
# 2258   46  Female             PhD  Director of Data Science
#
#       Years of Experience    Salary
# 2258                 20.0  220000.0

# %% [markdown]
# Highest Paid Staff of Undisclosed Gender

# %%
High_oth = Other[Other['Salary'] == Other['Salary'].max()]

# %%
High_oth
# Out:
#       Age Gender Education Level                Job Title  \
# 2376   53  Other     High School  Senior Project Engineer
# 2456   53  Other     High School  Senior Project Engineer
#
#       Years of Experience    Salary
# 2376                 31.0  166109.0
# 2456                 31.0  166109.0

# %% [markdown]
# Lowest Salary Earned By Gender

# %%
Min = salaries.groupby('Gender')['Salary'].min()

# %%
Min
# Out:
# Gender
# Female      500.0
# Male        350.0
# Other     62852.0
# Name: Salary, dtype: float64

# %% [markdown]
# Lowest Earning Male

# %%
Lowest_Paid_males = Males[Males['Salary'] == Males['Salary'].min()]

# %%
Lowest_Paid_males
# Out:
#      Age Gender     Education Level                           Job Title  \
# 258   29   Male  Barchelor's Degree  Junior Business Operations Analyst
#
#      Years of Experience  Salary
# 258                  1.5   350.0

# %% [markdown]
# Lowest Earning Female

# %%
Lowest_Paid_Female = Females[Females['Salary'] == Females['Salary'].min()]

# %%
Lowest_Paid_Female
# Out:
#       Age  Gender     Education Level              Job Title  \
# 4631   31  Female  Barchelor's Degree  Junior HR Coordinator
#
#       Years of Experience  Salary
# 4631                  4.0   500.0

# %% [markdown]
# Lowest Earning Undisclosed Gender

# %%
Low_oth = Other[Other['Salary'] == Other['Salary'].min()]

# %%
Low_oth
# Out:
#       Age Gender Education Level            Job Title  Years of Experience  \
# 2452   23  Other     High School  Front end Developer                  2.0
# 2532   23  Other     High School  Front end Developer                  2.0
#
#        Salary
# 2452  62852.0
# 2532  62852.0

# %% [markdown]
# Average Salary By Gender

# %%
Sal_Sex = salaries.groupby('Gender')['Salary'].mean()

# %%
Sal_Sex
# Out:
# Gender
# Female    107888.998672
# Male      121395.697630
# Other     125869.857143
# Name: Salary, dtype: float64

# %% [markdown]
# Visualization of Average Salary Earned by Gender

# %%
sns.barplot(x = "Gender", y = "Salary", data = salaries)
# Out:
# <Axes: xlabel='Gender', ylabel='Salary'>

# %% [markdown]
# Analysis:

# %% [markdown]
# The Highest Paid Salary was 250,000 and the lowest Paid Salary is 350 and the Average Salary given to the staffs in the company is 115326.9.  Among the Employees, three Genders were Represented (Male, Female and Others). The Highest Paid Male Employees were 3 in number and they were all earning 250,000 while the highest Paid Female was paid 220,000 and the highest paid Non Binary (Others) were paid 166,109. The Lowest Salary earned by the male Gender is 350 while that of the female Gender is  500 while that of those who identify as others is 62,852. However when we we check the average salary across each Gender, we see that those who Identify as others edge it slightly as they earn about 125869.86 compared to 121389.87 and  107888.99 for the male and Female Genders respectively. Among the Genders represented Male were the most employed, making up about 54.8 percent (3674 out of 6702) of the employees while Women occupy about 45% with 0.2 percent identifying as Others.

# %% [markdown]
# Average Salaries by Years of Experience

# %%
Sal_Exp = salaries.groupby('Years of Experience')['Salary'].mean()

# %%
Sal_Exp
# Out:
# Years of Experience
# 0.0      29680.233333
# 0.5      35000.000000
# 1.0      46992.846296
# 1.5      36279.166667
# 2.0      58699.457377
# 3.0      72944.406977
# 4.0      83332.090038
# 5.0     103111.092732
# 6.0     111891.146119
# 7.0     122171.039773
# 8.0     126438.138824
# 9.0     138021.460526
# 10.0    131690.322917
# 11.0    153060.318750
# 12.0    153398.064626
# 13.0    153002.181818
# 14.0    168632.363636
# 15.0    160664.759690
# 16.0    183285.438017
# 17.0    184053.830189
# 18.0    184340.412698
# 19.0    182430.330579
# 20.0    182288.721311
# 21.0    176734.190476
# 22.0    188644.531915
# 23.0    189573.702703
# 24.0    211225.421053
# 25.0    177803.458333
# 26.0    187717.285714
# 27.0    187922.636364
# 28.0    189774.812500
# 29.0    181437.000000
# 30.0    163339.833333
# 31.0    183027.200000
# 32.0    192540.800000
# 33.0    186400.666667
# 34.0    188651.000000
# Name: Salary, dtype: float64

# %%
sns.scatterplot(x= "Years of Experience", y= "Salary", data = salaries)
# Out:
# <Axes: xlabel='Years of Experience', ylabel='Salary'>

# %% [markdown]
# Average Salary Given Based on Educational Level

# %%
by_edu = salaries.groupby("Education Level").mean("Salary")

# %%
by_edu
# Out:
#                           Age  Years of Experience         Salary
# Education Level
# Barchelor's Degree  30.260179             5.419563   95082.908640
# High School         26.854911             1.915179   36706.694196
# Master's Degree     35.171505             9.645699  130112.056452
# PhD                 41.154858            13.915267  165651.457999

# %% [markdown]
# Visual Description of Data

# %% [markdown]
# Average Salary Earned by Educational Level

# %%
sns.barplot(x = "Education Level", y = "Salary", data = salaries)
# Out:
# <Axes: xlabel='Education Level', ylabel='Salary'>

# %% [markdown]
# The Average Salary by Educational Level as shown in the Output above tells us that salary increases with educational Level.

# %% [markdown]
# Relationship between Experience and Highest Educational Level

# %% [markdown]
# For PhD Holders

# %% [markdown]
# No of PhD holders with 0 to 5 years Experience

# %%
PhD = salaries[(salaries["Education Level"] == 'PhD') & (salaries["Years of Experience"] >= 0) & (salaries["Years of Experience"] <= 5)]

# %%
PhD
# Out:
#       Age  Gender Education Level             Job Title  Years of Experience  \
# 377    30    Male             PhD        Data Scientist                  5.0
# 385    27    Male             PhD        Data Scientist                  2.0
# 396    30  Female             PhD        Data Scientist                  5.0
# 404    27    Male             PhD        Data Scientist                  2.0
# 415    30  Female             PhD        Data Scientist                  5.0
# ...   ...     ...             ...                   ...                  ...
# 6638   28    Male             PhD  Sales Representative                  4.0
# 6652   28    Male             PhD     Marketing Manager                  4.0
# 6666   28    Male             PhD  Sales Representative                  4.0
# 6680   28    Male             PhD     Marketing Manager                  4.0
# 6694   28    Male             PhD  Sales Representative                  4.0
#
#         Salary
# 377   180000.0
# ...

# %% [markdown]
# No of PhD Holders with 6 to 10 years experience

# %%
PhD_1 = salaries[(salaries["Education Level"] == 'PhD') & (salaries["Years of Experience"] >= 6) & (salaries["Years of Experience"] <= 10)]

# %%
PhD_1
# Out:
#       Age  Gender Education Level                         Job Title  \
# 9      38    Male             PhD                  Senior Scientist
# 381    33    Male             PhD                    Data Scientist
# 389    33    Male             PhD                    Data Scientist
# 400    33    Male             PhD                    Data Scientist
# 408    33    Male             PhD                    Data Scientist
# ...   ...     ...             ...                               ...
# 6633   36  Female             PhD                 Marketing Manager
# 6647   36  Female             PhD  Senior Product Marketing Manager
# 6661   36  Female             PhD                 Marketing Manager
# 6675   36  Female             PhD  Senior Product Marketing Manager
# 6689   36  Female             PhD                 Marketing Manager
#
#       Years of Experience    Salary
# 9                    10.0  110000.0
# 381                   8.0  190000.0
# 389                   8.0  190000.0
# ...

# %% [markdown]
# No of PhD Holders with 11 to 15 years Experience

# %%
PhD_2 = salaries[(salaries["Education Level"] == 'PhD') & (salaries["Years of Experience"] >= 11) & (salaries["Years of Experience"] <= 15)]

# %%
PhD_2
# Out:
#       Age  Gender Education Level                         Job Title  \
# 2      45    Male             PhD                    Senior Manager
# 17     39    Male             PhD                   Senior Engineer
# 28     43  Female             PhD                 Senior Consultant
# 48     38    Male             PhD                  Senior Scientist
# 90     36    Male             PhD               Principal Scientist
# ...   ...     ...             ...                               ...
# 6266   50    Male             PhD  Senior Product Marketing Manager
# 6282   40    Male             PhD                    Sales Director
# 6300   50    Male             PhD  Senior Product Marketing Manager
# 6305   45  Female             PhD                 Financial Manager
# 6456   42    Male             PhD         Content Marketing Manager
#
#       Years of Experience    Salary
# 2                    15.0  150000.0
# 17                   12.0  115000.0
# 28                   15.0  140000.0
# ...

# %% [markdown]
# No of PhD Holders with 16 to 20 years Experience

# %%
PhD_3 = salaries[(salaries["Education Level"] == 'PhD') & (salaries["Years of Experience"] >= 16) & (salaries["Years of Experience"] <= 20)]

# %%
PhD_3
# Out:
#       Age  Gender Education Level                         Job Title  \
# 34     46    Male             PhD                    Senior Manager
# 57     43    Male             PhD                   Senior Engineer
# 72     45    Male             PhD                 Research Director
# 105    44    Male             PhD                Chief Data Officer
# 117    48    Male             PhD                Principal Engineer
# ...   ...     ...             ...                               ...
# 6641   49  Female             PhD             Director of Marketing
# 6655   49  Female             PhD  Senior Product Marketing Manager
# 6669   49  Female             PhD             Director of Marketing
# 6683   49  Female             PhD  Senior Product Marketing Manager
# 6697   49  Female             PhD             Director of Marketing
#
#       Years of Experience    Salary
# 34                   20.0  170000.0
# 57                   17.0  140000.0
# 72                   16.0  190000.0
# ...

# %% [markdown]
# No of PhD Holders with more than 20 years Experience

# %%
PhD_4 = salaries[(salaries["Education Level"] == 'PhD') & (salaries["Years of Experience"] >= 21)]

# %%
PhD_4
# Out:
#       Age  Gender Education Level                    Job Title  \
# 63     47    Male             PhD        Senior Data Scientist
# 83     52    Male             PhD     Chief Technology Officer
# 96     47    Male             PhD           Research Scientist
# 133    47    Male             PhD    Senior Research Scientist
# 158    51  Female             PhD  Director of Human Resources
# ...   ...     ...             ...                          ...
# 4451   48    Male             PhD               Data Scientist
# 4466   48    Male             PhD               Data Scientist
# 4481   48    Male             PhD               Data Scientist
# 4496   48    Male             PhD               Data Scientist
# 4511   48    Male             PhD               Data Scientist
#
#       Years of Experience    Salary
# 63                   21.0  180000.0
# 83                   24.0  250000.0
# 96                   22.0  160000.0
# 133                  22.0  160000.0
# ...

# %% [markdown]
# Visual Distribution of PhD holders by Years of Experience

# %%
# Creating a Dataset
PhD_Experience = ["0-5 years", "6-10 years", "11-15 years", "16-20 years", "Over 20 years"]
PhD_List = [(len(PhD.index)),(len(PhD_1.index)),(len(PhD_2.index)),(len(PhD_3.index)),(len(PhD_4.index))]

# Creating a plot
fig = plt.figure()
plt.pie(PhD_List, labels = PhD_Experience)
# Out:
# ([<matplotlib.patches.Wedge at 0x16a01615010>,
# ...
#  [Text(1.0862391212802582, 0.17344904554448526, '0-5 years'),
#   Text(0.7056688144271908, 0.8438196041482582, '6-10 years'),
#   Text(-0.9540970624557903, 0.5474475275432632, '11-15 years'),
#   Text(0.1045998405282757, -1.0950154671790986, '16-20 years'),
#   Text(1.068821202101184, -0.2600408389829954, 'Over 20 years')])

# %% [markdown]
# For Master's Degree Holders

# %% [markdown]
# No of Master's Degree holders with 0 to 5 years experience

# %%
Ma = salaries[(salaries["Education Level"] == "Master's Degree") & (salaries["Years of Experience"] >= 0) & (salaries["Years of Experience"] <= 5)]

# %%
Ma
# Out:
#       Age  Gender  Education Level                  Job Title  \
# 1      28  Female  Master's Degree               Data Analyst
# 10     29    Male  Master's Degree         Software Developer
# 20     34  Female  Master's Degree           Business Analyst
# 32     29    Male  Master's Degree             Data Scientist
# 40     34  Female  Master's Degree                UX Designer
# ...   ...     ...              ...                        ...
# 6310   26    Male  Master's Degree       Sales Representative
# 6326   27    Male  Master's Degree  Digital Marketing Manager
# 6351   27    Male  Master's Degree  Digital Marketing Manager
# 6463   27  Female  Master's Degree  Digital Marketing Manager
# 6587   28  Female  Master's Degree  Digital Marketing Manager
#
#       Years of Experience   Salary
# 1                     3.0  65000.0
# 10                    3.0  75000.0
# 20                    5.0  80000.0
# 32                    3.0  75000.0
# 40                    5.0  80000.0
# ...

# %% [markdown]
# No of Master's Degree holders with 6 to 10 years experience

# %%
Ma_1 = salaries[(salaries["Education Level"] == "Master's Degree") & (salaries["Years of Experience"] >= 6) & (salaries["Years of Experience"] <= 10)]

# %%
Ma_1
# Out:
#       Age  Gender  Education Level                      Job Title  \
# 16     33  Female  Master's Degree              Marketing Manager
# 29     33    Male  Master's Degree               Product Designer
# 51     33    Male  Master's Degree  Business Intelligence Analyst
# 59     35    Male  Master's Degree                Product Manager
# 65     38  Female  Master's Degree      Digital Marketing Manager
# ...   ...     ...              ...                            ...
# 6280   38    Male  Master's Degree          Director of Marketing
# 6291   39  Female  Master's Degree          Director of Marketing
# 6322   38    Male  Master's Degree          Director of Marketing
# 6334   33  Female  Master's Degree      Content Marketing Manager
# 6347   38    Male  Master's Degree          Director of Marketing
#
#       Years of Experience    Salary
# 16                    7.0   90000.0
# 29                    6.0   90000.0
# 51                    7.0   85000.0
# ...

# %% [markdown]
# No of Master's Degree holders with 11 to 15 years experience

# %%
Ma_2 = salaries[(salaries["Education Level"] == "Master's Degree") & (salaries["Years of Experience"] >= 11) & (salaries["Years of Experience"] <= 15)]

# %%
Ma_2
# Out:
#       Age  Gender  Education Level                  Job Title  \
# 6      42  Female  Master's Degree            Product Manager
# 13     40  Female  Master's Degree            Project Manager
# 24     41    Male  Master's Degree          Financial Manager
# 26     37  Female  Master's Degree           Software Manager
# 37     42    Male  Master's Degree           Project Engineer
# ...   ...     ...              ...                        ...
# 6663   43  Female  Master's Degree              Sales Manager
# 6672   46    Male  Master's Degree          Marketing Manager
# 6677   43  Female  Master's Degree  Digital Marketing Manager
# 6691   43  Female  Master's Degree              Sales Manager
# 6700   46    Male  Master's Degree          Marketing Manager
#
#       Years of Experience    Salary
# 6                    12.0  120000.0
# 13                   14.0  130000.0
# 24                   13.0  140000.0
# 26                   11.0  110000.0
# ...

# %% [markdown]
# No of Master's Degree holders with 16 to 20 years experience

# %%
Ma_3 = salaries[(salaries["Education Level"] == "Master's Degree") & (salaries["Years of Experience"] >= 16) & (salaries["Years of Experience"] <= 20)]

# %%
Ma_3
# Out:
#       Age  Gender  Education Level                         Job Title  \
# 4      52    Male  Master's Degree                          Director
# 21     47    Male  Master's Degree                  VP of Operations
# 41     48    Male  Master's Degree               Operations Director
# 47     45  Female  Master's Degree             Director of Marketing
# 53     47    Male  Master's Degree                     VP of Finance
# ...   ...     ...              ...                               ...
# 6658   46    Male  Master's Degree             Director of Marketing
# 6667   51  Female  Master's Degree  Senior Product Marketing Manager
# 6681   51  Female  Master's Degree         Content Marketing Manager
# 6686   46    Male  Master's Degree             Director of Marketing
# 6695   51  Female  Master's Degree  Senior Product Marketing Manager
#
#       Years of Experience    Salary
# 4                    20.0  200000.0
# 21                   19.0  190000.0
# ...

# %% [markdown]
# No of Master's Degree Holders with more than 20 years experience

# %%
Ma_4 = salaries[(salaries["Education Level"] == "Master's Degree") & (salaries["Years of Experience"] >= 21)]

# %%
Ma_4
# Out:
#       Age  Gender  Education Level                  Job Title  \
# 60     51  Female  Master's Degree     Director of Operations
# 88     46    Male  Master's Degree     Senior Project Manager
# 93     52  Female  Master's Degree   Senior Marketing Manager
# 121    53    Male  Master's Degree      Director of Marketing
# 130    50  Female  Master's Degree     Director of Operations
# ...   ...     ...              ...                        ...
# 3090   50  Female  Master's Degree    Senior Project Engineer
# 3115   50  Female  Master's Degree   Senior Software Engineer
# 3121   45  Female  Master's Degree  Software Engineer Manager
# 3129   50  Female  Master's Degree   Senior Software Engineer
# 4395   49    Male  Master's Degree          Marketing Manager
#
#       Years of Experience    Salary
# 60                   23.0  170000.0
# 88                   21.0  135000.0
# 93                   25.0  170000.0
# 121                  25.0  180000.0
# ...

# %%
Ma_4
# Out:
#       Age  Gender  Education Level                  Job Title  \
# 60     51  Female  Master's Degree     Director of Operations
# 88     46    Male  Master's Degree     Senior Project Manager
# 93     52  Female  Master's Degree   Senior Marketing Manager
# 121    53    Male  Master's Degree      Director of Marketing
# 130    50  Female  Master's Degree     Director of Operations
# ...   ...     ...              ...                        ...
# 3090   50  Female  Master's Degree    Senior Project Engineer
# 3115   50  Female  Master's Degree   Senior Software Engineer
# 3121   45  Female  Master's Degree  Software Engineer Manager
# 3129   50  Female  Master's Degree   Senior Software Engineer
# 4395   49    Male  Master's Degree          Marketing Manager
#
#       Years of Experience    Salary
# 60                   23.0  170000.0
# 88                   21.0  135000.0
# 93                   25.0  170000.0
# 121                  25.0  180000.0
# ...

# %% [markdown]
# Visualization of Master's Student by Years of Experience

# %%
# Creating a Dataset
Ma_Experience = ["0-5 years", "6-10 years", "11-15 years", "16-20 years", "Over 20 years"]
Ma_List = [(len(Ma.index)),(len(Ma_1.index)),(len(Ma_2.index)),(len(Ma_3.index)),(len(Ma_4.index))]

# Creating a plot
fig = plt.figure()
plt.pie(Ma_List, labels = Ma_Experience)
# Out:
# ([<matplotlib.patches.Wedge at 0x16a017b6dd0>,
# ...
#  [Text(0.8996440921265926, 0.6329616951299022, '0-5 years'),
#   Text(-0.9164189434646683, 0.6084211699629634, '6-10 years'),
#   Text(0.016720823302117136, -1.099872908143527, '11-15 years'),
#   Text(0.9697848237793857, -0.5191506482392044, '16-20 years'),
#   Text(1.0899733723350244, -0.14818248074794294, 'Over 20 years')])

# %% [markdown]
# For High School Degree

# %% [markdown]
# No of People with High School Degrees with 0 to 5 years experience

# %%
High_School1 = salaries[(salaries["Education Level"] == 'High School') & (salaries["Years of Experience"] >= 0) & (salaries["Years of Experience"] <= 5)]

# %%
High_School1
# Out:
#       Age  Gender Education Level                    Job Title  \
# 2383   25   Other     High School          Full Stack Engineer
# 2409   24  Female     High School      Senior Project Engineer
# 2434   22  Female     High School           Back end Developer
# 2452   23   Other     High School          Front end Developer
# 2463   25   Other     High School          Full Stack Engineer
# ...   ...     ...             ...                          ...
# 6684   32    Male     High School  Junior Sales Representative
# 6687   26  Female     High School              Sales Associate
# 6692   27    Male     High School    Digital Marketing Manager
# 6698   32    Male     High School              Sales Associate
# 6701   26  Female     High School              Sales Executive
#
#       Years of Experience   Salary
# 2383                  2.0  69032.0
# 2409                  1.0  52731.0
# 2434                  0.0  51832.0
# 2452                  2.0  62852.0
# ...

# %% [markdown]
# Number of People with High School Degrees with 6 to 10 years Experience

# %%
High_School2 = salaries[(salaries["Education Level"] == 'High School') & (salaries["Years of Experience"] > 5)  & (salaries["Years of Experience"] <= 10)]

# %%
High_School2
# Out:
#       Age Gender Education Level           Job Title  Years of Experience  \
# 2401   28   Male     High School  Back end Developer                  7.0
# 2446   31  Other     High School  Back end Developer                  8.0
# 2481   28   Male     High School  Back end Developer                  7.0
# 2526   31  Other     High School  Back end Developer                  8.0
#
#         Salary
# 2401   95845.0
# 2446  104127.0
# 2481   95845.0
# 2526  104127.0

# %% [markdown]
# Number of People with High School Degrees with more than 10 years Experience

# %%
High_School3 = salaries[(salaries["Education Level"] == 'High School') & (salaries["Years of Experience"] > 10)  & (salaries["Years of Experience"] <= 35)]

# %%
High_School3
# Out:
#       Age  Gender Education Level                 Job Title  \
# 2376   53   Other     High School   Senior Project Engineer
# 2393   30    Male     High School   Senior Project Engineer
# 2418   43    Male     High School  Senior Software Engineer
# 2427   49  Female     High School   Senior Project Engineer
# 2456   53   Other     High School   Senior Project Engineer
# 2473   30    Male     High School   Senior Project Engineer
# 2498   43    Male     High School  Senior Software Engineer
# 2507   49  Female     High School   Senior Project Engineer
# 2552   54   Other     High School  Senior Software Engineer
# 2798   54   Other     High School  Senior Software Engineer
# 2917   54   Other     High School  Senior Software Engineer
# 3036   54   Other     High School  Senior Software Engineer
#
#       Years of Experience    Salary
# 2376                 31.0  166109.0
# 2393                 11.0  103947.0
# 2418                 22.0  165919.0
# ...

# %% [markdown]
# Visualization of High School Degree Holders by Years of Experience

# %%
# Creating a Dataset
HS_Experience = ["0-5 years", "6-10 years", "Over 11 years"]
HS_List = [(len(High_School1.index)),(len(High_School2.index)),(len(High_School3.index))]

# Creating a plot
fig = plt.figure()
plt.pie(HS_List, labels = HS_Experience)
# Out:
# ([<matplotlib.patches.Wedge at 0x16a096fcf50>,
# ...
#  [Text(-1.0930834374717984, 0.12316086523257752, '0-5 years'),
#   Text(1.0788638316752017, -0.21459923742432632, '6-10 years'),
#   Text(1.0961076537314611, -0.09245545647127401, 'Over 11 years')])

# %% [markdown]
# For those with Barchelor's Degree

# %%
B_D = salaries[(salaries["Education Level"] == "Barchelor's Degree") &  (salaries["Years of Experience"] >= 0) & (salaries["Years of Experience"] <= 5)]

# %%
B_D
# Out:
#       Age  Gender     Education Level              Job Title  \
# 0      32    Male  Barchelor's Degree      Software Engineer
# 5      29    Male  Barchelor's Degree      Marketing Analyst
# 7      31    Male  Barchelor's Degree          Sales Manager
# 8      26  Female  Barchelor's Degree  Marketing Coordinator
# 14     27    Male  Barchelor's Degree   Customer Service Rep
# ...   ...     ...                 ...                    ...
# 6671   30  Female  Barchelor's Degree      Financial Manager
# 6676   24    Male  Barchelor's Degree   Sales Representative
# 6685   30  Female  Barchelor's Degree          Sales Manager
# 6690   24    Male  Barchelor's Degree        Sales Executive
# 6699   30  Female  Barchelor's Degree      Financial Manager
#
#       Years of Experience   Salary
# 0                     5.0  90000.0
# 5                     2.0  55000.0
# 7                     4.0  80000.0
# 8                     1.0  45000.0
# 14                    2.0  40000.0
# ...

# %% [markdown]
# Number of Barchelor's Degree Holders with 6 to 10 year Experience

# %%
B_D1 = salaries[(salaries["Education Level"] == "Barchelor's Degree") &  (salaries["Years of Experience"] >= 6) & (salaries["Years of Experience"] <= 10)]

# %%
B_D1
# Out:
#       Age  Gender     Education Level                    Job Title  \
# 3      36  Female  Barchelor's Degree              Sales Associate
# 12     35    Male  Barchelor's Degree            Financial Analyst
# 23     36  Female  Barchelor's Degree                    Recruiter
# 33     39  Female  Barchelor's Degree         Marketing Specialist
# 36     35  Female  Barchelor's Degree                HR Generalist
# ...   ...     ...                 ...                          ...
# 6668   37    Male  Barchelor's Degree  Junior Sales Representative
# 6679   33  Female  Barchelor's Degree        Director of Marketing
# 6682   37    Male  Barchelor's Degree               Sales Director
# 6693   33  Female  Barchelor's Degree    Content Marketing Manager
# 6696   37    Male  Barchelor's Degree  Junior Sales Representative
#
#       Years of Experience   Salary
# 3                     7.0  60000.0
# 12                    6.0  65000.0
# 23                    9.0  60000.0
# ...

# %% [markdown]
# No of Bachelor's Degree Holders with 11 to 15 years experience

# %%
B_D2 = salaries[(salaries["Education Level"] == "Barchelor's Degree") &  (salaries["Years of Experience"] >= 11) & (salaries["Years of Experience"] <= 15)]

# %%
B_D2
# Out:
#       Age  Gender     Education Level                  Job Title  \
# 52     40  Female  Barchelor's Degree          Event Coordinator
# 62     40  Female  Barchelor's Degree                 HR Manager
# 71     39  Female  Barchelor's Degree                  Recruiter
# 87     40  Female  Barchelor's Degree              HR Generalist
# 95     39  Female  Barchelor's Degree        Training Specialist
# ...   ...     ...                 ...                        ...
# 6632   42    Male  Barchelor's Degree          Financial Manager
# 6646   42    Male  Barchelor's Degree  Content Marketing Manager
# 6660   42    Male  Barchelor's Degree          Financial Manager
# 6674   42    Male  Barchelor's Degree  Content Marketing Manager
# 6688   42    Male  Barchelor's Degree          Financial Manager
#
#       Years of Experience    Salary
# 52                   12.0   60000.0
# 62                   12.0   80000.0
# 71                   11.0   70000.0
# 87                   15.0   80000.0
# ...

# %% [markdown]
# No of People with Bachelors Degree with 16 to 20 years Experience

# %%
B_D3 = salaries[(salaries["Education Level"] == "Barchelor's Degree") & (salaries["Years of Experience"] >= 16) & (salaries["Years of Experience"] <= 20)]

# %%
B_D3
# Out:
#       Age  Gender     Education Level             Job Title  \
# 11     48  Female  Barchelor's Degree            HR Manager
# 15     44    Male  Barchelor's Degree    Operations Manager
# 66     46    Male  Barchelor's Degree            IT Manager
# 92     43    Male  Barchelor's Degree  Supply Chain Manager
# 99     45    Male  Barchelor's Degree    Operations Analyst
# ...   ...     ...                 ...                   ...
# 6212   40  Female  Barchelor's Degree     Financial Manager
# 6226   40  Female  Barchelor's Degree     Financial Manager
# 6240   40  Female  Barchelor's Degree     Financial Manager
# 6254   40  Female  Barchelor's Degree     Financial Manager
# 6336   50  Female  Barchelor's Degree         Sales Manager
#
#       Years of Experience    Salary
# 11                   18.0  140000.0
# 15                   16.0  125000.0
# 66                   19.0  120000.0
# 92                   18.0  105000.0
# 99                   20.0  110000.0
# ...

# %% [markdown]
# No of People with Bachelors Degree with more than 20 years Experience

# %%
B_D4 = salaries[(salaries["Education Level"] == "Barchelor's Degree") & (salaries["Years of Experience"] >= 20)]

# %%
B_D4
# Out:
#       Age  Gender     Education Level                 Job Title  \
# 19     51    Male  Barchelor's Degree            Sales Director
# 30     50    Male  Barchelor's Degree                       CEO
# 39     49    Male  Barchelor's Degree           Sales Executive
# 50     51  Female  Barchelor's Degree  Customer Service Manager
# 76     50  Female  Barchelor's Degree        Operations Manager
# ...   ...     ...                 ...                       ...
# 3072   45  Female  Barchelor's Degree   Senior Project Engineer
# 3094   48  Female  Barchelor's Degree   Senior Project Engineer
# 3112   43    Male  Barchelor's Degree   Senior Project Engineer
# 3133   48  Female  Barchelor's Degree   Senior Project Engineer
# 4999   45    Male  Barchelor's Degree         Financial Manager
#
#       Years of Experience    Salary
# 19                   22.0  180000.0
# 30                   25.0  250000.0
# 39                   21.0  160000.0
# 50                   22.0  130000.0
# ...

# %% [markdown]
# Visualization of Barchelor's Degree holders by Year's of Experience

# %%
# Creating a Dataset
Ba_Experience = ["0-5 years", "6-10 years", "11-15 years", "16-20 years", "Over 20 years"]
Ba_List = [(len(B_D.index)),(len(B_D.index)),(len(B_D2.index)),(len(B_D3.index)),(len(B_D4.index))]

# Creating a plot
fig = plt.figure()
plt.pie(Ba_List, labels = Ba_Experience)
# Out:
# ([<matplotlib.patches.Wedge at 0x16a098d34d0>,
# ...
#  [Text(0.1383374507772003, 1.0912665804983062, '0-5 years'),
#   Text(-0.406260622018666, -1.0222290873365945, '6-10 years'),
#   Text(1.027138691569292, -0.39368275080491316, '11-15 years'),
#   Text(1.0858292241429932, -0.17599686359996847, '16-20 years'),
#   Text(1.0987921204302948, -0.0515351926385899, 'Over 20 years')])

# %% [markdown]
# Also, we see a positive correlation between Years of Experience and the Educatonal Level of the Employees (i.e Those with Higher Educational Qualification have more years of Experience than those with Lower Educational Level/Qualification). We see that 89% (2,696 out of 3,023) of Barchelor's Degree Holders have Years of Experience between 0 - 10 years and 97.32 percent (436 out of 448) of high School Degree holders have Years Of Experience of between 0 - 10 years. When we compare to the for Master's and PhD degree holders where just 61.8 percent and 22.1 percent have below 10 years Experience.

# %% [markdown]
# No of PhD Degree Holders

# %%
No_of_PhD = salaries[salaries["Education Level"] == "PhD"]

# %%
No_of_PhD
# Out:
#       Age  Gender Education Level                         Job Title  \
# 2      45    Male             PhD                    Senior Manager
# 9      38    Male             PhD                  Senior Scientist
# 17     39    Male             PhD                   Senior Engineer
# 28     43  Female             PhD                 Senior Consultant
# 34     46    Male             PhD                    Senior Manager
# ...   ...     ...             ...                               ...
# 6680   28    Male             PhD                 Marketing Manager
# 6683   49  Female             PhD  Senior Product Marketing Manager
# 6689   36  Female             PhD                 Marketing Manager
# 6694   28    Male             PhD              Sales Representative
# 6697   49  Female             PhD             Director of Marketing
#
#       Years of Experience    Salary
# 2                    15.0  150000.0
# 9                    10.0  110000.0
# 17                   12.0  115000.0
# ...

# %% [markdown]
# No of Master's Degree Holders

# %%
No_of_Mas = salaries[salaries["Education Level"] == "Master's Degree"]

# %%
No_of_Mas
# Out:
#       Age  Gender  Education Level                         Job Title  \
# 1      28  Female  Master's Degree                      Data Analyst
# 4      52    Male  Master's Degree                          Director
# 6      42  Female  Master's Degree                   Product Manager
# 10     29    Male  Master's Degree                Software Developer
# 13     40  Female  Master's Degree                   Project Manager
# ...   ...     ...              ...                               ...
# 6681   51  Female  Master's Degree         Content Marketing Manager
# 6686   46    Male  Master's Degree             Director of Marketing
# 6691   43  Female  Master's Degree                     Sales Manager
# 6695   51  Female  Master's Degree  Senior Product Marketing Manager
# 6700   46    Male  Master's Degree                 Marketing Manager
#
#       Years of Experience    Salary
# 1                     3.0   65000.0
# 4                    20.0  200000.0
# ...

# %% [markdown]
# No of Barchelor's Degree Holders

# %%
No_of_Bar = salaries[salaries["Education Level"] == "Barchelor's Degree"]

# %%
No_of_Bar
# Out:
#       Age  Gender     Education Level                    Job Title  \
# 0      32    Male  Barchelor's Degree            Software Engineer
# 3      36  Female  Barchelor's Degree              Sales Associate
# 5      29    Male  Barchelor's Degree            Marketing Analyst
# 7      31    Male  Barchelor's Degree                Sales Manager
# 8      26  Female  Barchelor's Degree        Marketing Coordinator
# ...   ...     ...                 ...                          ...
# 6688   42    Male  Barchelor's Degree            Financial Manager
# 6690   24    Male  Barchelor's Degree              Sales Executive
# 6693   33  Female  Barchelor's Degree    Content Marketing Manager
# 6696   37    Male  Barchelor's Degree  Junior Sales Representative
# 6699   30  Female  Barchelor's Degree            Financial Manager
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 3                     7.0   60000.0
# 5                     2.0   55000.0
# ...

# %%
No_of_H = salaries[salaries["Education Level"] == "High School"]

# %%
No_of_H
# Out:
#       Age  Gender Education Level                    Job Title  \
# 2376   53   Other     High School      Senior Project Engineer
# 2383   25   Other     High School          Full Stack Engineer
# 2393   30    Male     High School      Senior Project Engineer
# 2401   28    Male     High School           Back end Developer
# 2409   24  Female     High School      Senior Project Engineer
# ...   ...     ...             ...                          ...
# 6684   32    Male     High School  Junior Sales Representative
# 6687   26  Female     High School              Sales Associate
# 6692   27    Male     High School    Digital Marketing Manager
# 6698   32    Male     High School              Sales Associate
# 6701   26  Female     High School              Sales Executive
#
#       Years of Experience    Salary
# 2376                 31.0  166109.0
# 2383                  2.0   69032.0
# 2393                 11.0  103947.0
# 2401                  7.0   95845.0
# ...

# %% [markdown]
# Distribution of Data Set by Educational Level

# %%
sns.countplot(x = "Education Level", data = salaries)
# Out:
# <Axes: xlabel='Education Level', ylabel='count'>

# %% [markdown]
# From the Data, we see that Majority of the Employees in the Company have Barchelor's Degree holder as their highest degree with 3023 people which is about 45 percent of the total number of Employees. Followed by Master's Degree Holders who are 1861 people (about 27.7%) in Number with the least employed qualification being High School Degree (6.68%) and PhD Degree holders accounting for 20.62%.

# %% [markdown]
# Average Age needed to acquire year of Experience

# %%
Age_Exp = salaries.groupby("Years of Experience")["Age"].mean()

# %%
Age_Exp
# Out:
# Years of Experience
# 0.0     23.291667
# 0.5     23.000000
# 1.0     25.211111
# 1.5     27.833333
# 2.0     26.560656
# 3.0     27.745847
# 4.0     28.706897
# 5.0     29.659148
# 6.0     31.175799
# 7.0     31.713068
# 8.0     33.418824
# 9.0     33.707895
# 10.0    35.682292
# 11.0    36.584375
# 12.0    37.789116
# 13.0    40.717703
# 14.0    41.245059
# 15.0    43.899225
# 16.0    43.776860
# 17.0    49.858491
# 18.0    47.190476
# 19.0    47.239669
# 20.0    46.836066
# 21.0    46.571429
# 22.0    47.851064
# 23.0    48.513514
# 24.0    49.789474
# 25.0    50.500000
# 26.0    51.285714
# 27.0    53.272727
# 28.0    53.562500
# 29.0    53.583333
# 30.0    55.333333
# 31.0    54.000000
# 32.0    54.000000
# 33.0    58.000000
# 34.0    60.000000
# Name: Age, dtype: float64

# %%
sns.scatterplot(x= "Age", y= "Years of Experience", data = salaries)
# Out:
# <Axes: xlabel='Age', ylabel='Years of Experience'>

# %% [markdown]
# Average Salaries by Age

# %%
Sal_Age = salaries.groupby('Age')['Salary'].mean()

# %%
Sal_Age
# Out:
# Age
# 21     25000.000000
# 22     32910.933333
# 23     47192.009615
# 24     51052.250000
# 25     63730.387324
# 26     65949.106870
# 27     77388.994186
# 28     84140.368298
# 29     85764.750000
# 30    100903.955457
# 31    114381.461538
# 32    120500.179487
# 33    127425.266332
# 34    132065.291262
# 35    119365.835000
# 36    134071.725979
# 37    146939.461538
# 38    138185.570470
# 39    147282.715190
# 40    149862.989130
# 41    155235.565891
# 42    155952.477273
# 43    165409.398734
# 44    160518.873016
# 45    170334.291667
# 46    171242.362745
# 47    178750.106383
# 48    192723.846939
# 49    189013.582418
# 50    190849.897727
# 51    200356.066667
# 52    187629.379310
# 53    180806.571429
# 54    189816.250000
# 55    198482.187500
# 56    196577.636364
# 57    176993.777778
# 58    195715.428571
# 60    186132.400000
# 61    200000.000000
# 62    200000.000000
# Name: Salary, dtype: float64

# %% [markdown]
# Visualization of Average Salary Earned by Age

# %%
sns.scatterplot(x= "Age", y= "Salary", data = salaries)
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %% [markdown]
# Highest Degree obtained among age groups

# %% [markdown]
# People between 20 and 25 with Barchelor's Degree

# %%
Age_1 = salaries[(salaries['Age'] >= 20) & (salaries['Age'] <= 25) & (salaries["Education Level"] == "Barchelor's Degree")]

# %%
Age_1
# Out:
#       Age  Gender     Education Level                 Job Title  \
# 18     25  Female  Barchelor's Degree          Data Entry Clerk
# 27     24    Male  Barchelor's Degree          Junior Developer
# 49     25    Male  Barchelor's Degree         Help Desk Analyst
# 82     25    Male  Barchelor's Degree      Sales Representative
# 114    23  Female  Barchelor's Degree  Junior Marketing Analyst
# ...   ...     ...                 ...                       ...
# 6634   24    Male  Barchelor's Degree           Sales Executive
# 6648   24    Male  Barchelor's Degree      Sales Representative
# 6662   24    Male  Barchelor's Degree           Sales Executive
# 6676   24    Male  Barchelor's Degree      Sales Representative
# 6690   24    Male  Barchelor's Degree           Sales Executive
#
#       Years of Experience   Salary
# 18                    0.0  35000.0
# 27                    1.0  40000.0
# 49                    0.0  35000.0
# 82                    0.0  30000.0
# ...

# %% [markdown]
# No of people aged Between 26 to 30 with a Barchelor's Degree

# %%
Age_2 = salaries[(salaries['Age'] >= 26) & (salaries['Age'] <= 30) & (salaries["Education Level"] == "Barchelor's Degree")]

# %%
Age_2
# Out:
#       Age  Gender     Education Level                Job Title  \
# 5      29    Male  Barchelor's Degree        Marketing Analyst
# 8      26  Female  Barchelor's Degree    Marketing Coordinator
# 14     27    Male  Barchelor's Degree     Customer Service Rep
# 22     30    Male  Barchelor's Degree               IT Support
# 25     28  Female  Barchelor's Degree  Social Media Specialist
# ...   ...     ...                 ...                      ...
# 6643   30  Female  Barchelor's Degree        Financial Manager
# 6657   30  Female  Barchelor's Degree            Sales Manager
# 6671   30  Female  Barchelor's Degree        Financial Manager
# 6685   30  Female  Barchelor's Degree            Sales Manager
# 6699   30  Female  Barchelor's Degree        Financial Manager
#
#       Years of Experience   Salary
# 5                     2.0  55000.0
# 8                     1.0  45000.0
# 14                    2.0  40000.0
# 22                    2.0  50000.0
# ...

# %% [markdown]
# No of people aged between 31 and 35 years with a Barchelor's Degree

# %%
Age_3 = salaries[(salaries['Age'] >= 31) & (salaries['Age'] <= 35) & (salaries["Education Level"] == "Barchelor's Degree")]

# %%
Age_3
# Out:
#       Age  Gender     Education Level                  Job Title  \
# 0      32    Male  Barchelor's Degree          Software Engineer
# 7      31    Male  Barchelor's Degree              Sales Manager
# 12     35    Male  Barchelor's Degree          Financial Analyst
# 31     31  Female  Barchelor's Degree                 Accountant
# 36     35  Female  Barchelor's Degree              HR Generalist
# ...   ...     ...                 ...                        ...
# 6637   33  Female  Barchelor's Degree  Content Marketing Manager
# 6651   33  Female  Barchelor's Degree      Director of Marketing
# 6665   33  Female  Barchelor's Degree  Content Marketing Manager
# 6679   33  Female  Barchelor's Degree      Director of Marketing
# 6693   33  Female  Barchelor's Degree  Content Marketing Manager
#
#       Years of Experience   Salary
# 0                     5.0  90000.0
# 7                     4.0  80000.0
# 12                    6.0  65000.0
# 31                    4.0  55000.0
# ...

# %% [markdown]
# Number of people aged between 36 and 40 who have Barchelor's Degree

# %%
Age_4 = salaries[(salaries['Age'] >= 36) & (salaries['Age'] <= 40) & (salaries["Education Level"] == "Barchelor's Degree")]

# %%
Age_4
# Out:
#       Age  Gender     Education Level                    Job Title  \
# 3      36  Female  Barchelor's Degree              Sales Associate
# 23     36  Female  Barchelor's Degree                    Recruiter
# 33     39  Female  Barchelor's Degree         Marketing Specialist
# 43     36  Female  Barchelor's Degree     Administrative Assistant
# 52     40  Female  Barchelor's Degree            Event Coordinator
# ...   ...     ...                 ...                          ...
# 6640   37    Male  Barchelor's Degree  Junior Sales Representative
# 6654   37    Male  Barchelor's Degree               Sales Director
# 6668   37    Male  Barchelor's Degree  Junior Sales Representative
# 6682   37    Male  Barchelor's Degree               Sales Director
# 6696   37    Male  Barchelor's Degree  Junior Sales Representative
#
#       Years of Experience   Salary
# 3                     7.0  60000.0
# 23                    9.0  60000.0
# 33                   10.0  65000.0
# ...

# %% [markdown]
# No of people Aged between 41 and 45 with  Barchelor's Degree

# %%
Age_5 = salaries[(salaries['Age'] >= 41) & (salaries['Age'] <= 45) & (salaries["Education Level"] == "Barchelor's Degree")]

# %%
Age_5
# Out:
#       Age  Gender     Education Level                  Job Title  \
# 15     44    Male  Barchelor's Degree         Operations Manager
# 92     43    Male  Barchelor's Degree       Supply Chain Manager
# 99     45    Male  Barchelor's Degree         Operations Analyst
# 120    42  Female  Barchelor's Degree              Sales Manager
# 127    45    Male  Barchelor's Degree   Sales Operations Manager
# ...   ...     ...                 ...                        ...
# 6632   42    Male  Barchelor's Degree          Financial Manager
# 6646   42    Male  Barchelor's Degree  Content Marketing Manager
# 6660   42    Male  Barchelor's Degree          Financial Manager
# 6674   42    Male  Barchelor's Degree  Content Marketing Manager
# 6688   42    Male  Barchelor's Degree          Financial Manager
#
#       Years of Experience    Salary
# 15                   16.0  125000.0
# 92                   18.0  105000.0
# 99                   20.0  110000.0
# 120                  17.0  100000.0
# ...

# %% [markdown]
# No of people aged above 46 with Barchelor's Degree

# %%
Age_6= salaries[(salaries['Age'] >= 46) & (salaries["Education Level"] == "Barchelor's Degree")]

# %%
Age_6
# Out:
#       Age  Gender     Education Level                 Job Title  \
# 11     48  Female  Barchelor's Degree                HR Manager
# 19     51    Male  Barchelor's Degree            Sales Director
# 30     50    Male  Barchelor's Degree                       CEO
# 39     49    Male  Barchelor's Degree           Sales Executive
# 50     51  Female  Barchelor's Degree  Customer Service Manager
# 66     46    Male  Barchelor's Degree                IT Manager
# 76     50  Female  Barchelor's Degree        Operations Manager
# 112    50  Female  Barchelor's Degree      Supply Chain Analyst
# 143    47    Male  Barchelor's Degree      Senior Sales Manager
# 2382   49  Female  Barchelor's Degree        Back end Developer
# 2395   50    Male  Barchelor's Degree        Back end Developer
# 2400   46  Female  Barchelor's Degree  Senior Software Engineer
# 2414   52    Male  Barchelor's Degree        Back end Developer
# 2421   55    Male  Barchelor's Degree   Senior Project Engineer
# ...

# %% [markdown]
# Visual Discription

# %%
# Creating a Dataset
Bar_Age = ["20-25 years", "26-30 years", "31-35 years", "36-40 years", "41-45 years", "46 years and above"]
Ba_List = [(len(Age_1.index)),(len(Age_2.index)),(len(Age_3.index)),(len(Age_4.index)),(len(Age_5.index)),(len(Age_6.index))]

# Creating a plot
fig = plt.figure()
plt.pie(Ba_List, labels = Bar_Age)
# Out:
# ([<matplotlib.patches.Wedge at 0x16a090cad90>,
# ...
#  [Text(1.0138986853382295, 0.4266256624599722, '20-25 years'),
#   Text(-0.7804418316935902, 0.7751842022014859, '26-30 years'),
#   Text(-0.061167637648492194, -1.0982980106075504, '31-35 years'),
#   Text(0.9136223361957846, -0.6126126237714639, '36-40 years'),
#   Text(1.0769975451928544, -0.22377731710020582, '41-45 years'),
#   Text(1.0979997420979437, -0.06630660866647715, '46 years and above')])

# %% [markdown]
# Checking the various age groups with High School Degree as their highest qualification

# %% [markdown]
# No of people with aged between 20 and 25 years with High School degree as their highest Qualification

# %%
Age_H =  salaries[(salaries['Age'] >= 20) & (salaries['Age'] <= 25) & (salaries["Education Level"] == "High School")]

# %%
Age_H
# Out:
#       Age  Gender Education Level                Job Title  \
# 2383   25   Other     High School      Full Stack Engineer
# 2409   24  Female     High School  Senior Project Engineer
# 2434   22  Female     High School       Back end Developer
# 2452   23   Other     High School      Front end Developer
# 2463   25   Other     High School      Full Stack Engineer
# ...   ...     ...             ...                      ...
# 6535   25  Female     High School          Sales Executive
# 6549   25  Female     High School          Sales Executive
# 6563   25  Female     High School          Sales Executive
# 6577   25  Female     High School          Sales Executive
# 6584   25    Male     High School          Sales Associate
#
#       Years of Experience   Salary
# 2383                  2.0  69032.0
# 2409                  1.0  52731.0
# 2434                  0.0  51832.0
# 2452                  2.0  62852.0
# 2463                  2.0  69032.0
# ...                   ...      ...
# ...

# %% [markdown]
# People aged between 26 & 30 with High School Degree as their highest Degree

# %%
Age_H1 = salaries[(salaries['Age'] >= 26) & (salaries['Age'] <= 30) & (salaries["Education Level"] == "High School")]

# %%
Age_H1
# Out:
#       Age  Gender Education Level                  Job Title  \
# 2393   30    Male     High School    Senior Project Engineer
# 2401   28    Male     High School         Back end Developer
# 2473   30    Male     High School    Senior Project Engineer
# 2481   28    Male     High School         Back end Developer
# 2574   27    Male     High School         Back end Developer
# ...   ...     ...             ...                        ...
# 6673   26  Female     High School            Sales Executive
# 6678   27    Male     High School              Sales Manager
# 6687   26  Female     High School            Sales Associate
# 6692   27    Male     High School  Digital Marketing Manager
# 6701   26  Female     High School            Sales Executive
#
#       Years of Experience    Salary
# 2393                 11.0  103947.0
# 2401                  7.0   95845.0
# 2473                 11.0  103947.0
# 2481                  7.0   95845.0
# 2574                  4.0   79767.0
# ...

# %% [markdown]
# People aged between 31 and 35 with High School Degree as their Highest Degree

# %%
Age_H2 = salaries[(salaries['Age'] >= 31) & (salaries['Age'] <= 35) & (salaries["Education Level"] == "High School")]

# %%
Age_H2
# Out:
#       Age  Gender Education Level                    Job Title  \
# 2446   31   Other     High School           Back end Developer
# 2526   31   Other     High School           Back end Developer
# 3395   31    Male     High School         Junior Web Developer
# 3405   31  Female     High School        Junior HR Coordinator
# 3425   31    Male     High School         Junior HR Generalist
# 3433   33    Male     High School        Junior HR Coordinator
# 3444   31    Male     High School         Junior HR Generalist
# 3463   31    Male     High School         Junior HR Generalist
# 3482   31    Male     High School         Junior HR Generalist
# 3501   31    Male     High School         Junior HR Generalist
# 3524   31  Female     High School        Junior HR Coordinator
# 3544   31    Male     High School         Junior HR Generalist
# 3552   33    Male     High School        Junior HR Coordinator
# 3563   31    Male     High School         Junior HR Generalist
# ...

# %% [markdown]
# People aged above 40 with High School Degree as their Highest Degree

# %%
Age_H3 = salaries[(salaries['Age'] >= 36) & (salaries["Education Level"] == "High School")]

# %%
Age_H3
# Out:
#       Age  Gender Education Level                 Job Title  \
# 2376   53   Other     High School   Senior Project Engineer
# 2418   43    Male     High School  Senior Software Engineer
# 2427   49  Female     High School   Senior Project Engineer
# 2456   53   Other     High School   Senior Project Engineer
# 2498   43    Male     High School  Senior Software Engineer
# 2507   49  Female     High School   Senior Project Engineer
# 2552   54   Other     High School  Senior Software Engineer
# 2798   54   Other     High School  Senior Software Engineer
# 2917   54   Other     High School  Senior Software Engineer
# 3036   54   Other     High School  Senior Software Engineer
#
#       Years of Experience    Salary
# 2376                 31.0  166109.0
# 2418                 22.0  165919.0
# 2427                 25.0  154207.0
# 2456                 31.0  166109.0
# 2498                 22.0  165919.0
# 2507                 25.0  154207.0
# 2552                 29.0  158254.0
# ...

# %%
# Creating a Dataset
HS_Age = ["20-25 years", "26-30 years", "31-35 years", "36 and above"]
HS_List = [(len(Age_H.index)),(len(Age_H1.index)),(len(Age_H2.index)),(len(Age_H3.index))]

# Creating a plot
fig = plt.figure()
plt.pie(HS_List, labels = HS_Age)
# Out:
# ([<matplotlib.patches.Wedge at 0x16a0964c2d0>,
# ...
#  [Text(0.17664767635193138, 1.0857235368359035, '20-25 years'),
#   Text(-0.623894236308612, -0.9059558388248812, '26-30 years'),
#   Text(0.9589908508666333, -0.5388288670385902, '31-35 years'),
#   Text(1.0972964888784196, -0.0770740909456133, '36 and above')])

# %% [markdown]
# Checking the various age groups with Master's Degree as their highest qualification

# %% [markdown]
# Number of people aged between 20 and 25 years

# %%
Age_M = salaries[(salaries['Age'] >= 20) & (salaries['Age'] <= 25) & (salaries["Education Level"] == "Master's Degree")]

# %%
Age_M
# Out:
#       Age  Gender  Education Level                    Job Title  \
# 144    25  Female  Master's Degree  Junior Marketing Specialist
# 380    25  Female  Master's Degree                 Data Analyst
# 388    25  Female  Master's Degree                 Data Analyst
# 399    25  Female  Master's Degree                 Data Analyst
# 407    25  Female  Master's Degree                 Data Analyst
# 418    25  Female  Master's Degree                 Data Analyst
# 426    25  Female  Master's Degree                 Data Analyst
# 437    25  Female  Master's Degree                 Data Analyst
# 445    25  Female  Master's Degree                 Data Analyst
# 453    25  Female  Master's Degree                 Data Analyst
# 464    25  Female  Master's Degree                 Data Analyst
# 472    25  Female  Master's Degree                 Data Analyst
# 480    25  Female  Master's Degree                 Data Analyst
# 488    25  Female  Master's Degree                 Data Analyst
# ...

# %% [markdown]
# No of People Aged between 26 and 30 with Master's Degree as their Highest Qualification

# %%
Age_M1 = salaries[(salaries['Age'] >= 26) & (salaries['Age'] <= 30) & (salaries["Education Level"] == "Master's Degree")]

# %%
Age_M1
# Out:
#       Age  Gender  Education Level                  Job Title  \
# 1      28  Female  Master's Degree               Data Analyst
# 10     29    Male  Master's Degree         Software Developer
# 32     29    Male  Master's Degree             Data Scientist
# 56     27  Female  Master's Degree              UX Researcher
# 173    26  Female  Master's Degree      Junior Data Scientist
# ...   ...     ...              ...                        ...
# 6310   26    Male  Master's Degree       Sales Representative
# 6326   27    Male  Master's Degree  Digital Marketing Manager
# 6351   27    Male  Master's Degree  Digital Marketing Manager
# 6463   27  Female  Master's Degree  Digital Marketing Manager
# 6587   28  Female  Master's Degree  Digital Marketing Manager
#
#       Years of Experience   Salary
# 1                     3.0  65000.0
# 10                    3.0  75000.0
# 32                    3.0  75000.0
# 56                    2.0  65000.0
# 173                   1.5  45000.0
# ...

# %% [markdown]
# No of People aged between 31 and 35 who have Master's Degree as their Highest Qualification

# %%
Age_M2 = salaries[(salaries['Age'] >= 31) & (salaries['Age'] <= 35) & (salaries["Education Level"] == "Master's Degree")]

# %%
Age_M2
# Out:
#       Age  Gender  Education Level                      Job Title  \
# 16     33  Female  Master's Degree              Marketing Manager
# 20     34  Female  Master's Degree               Business Analyst
# 29     33    Male  Master's Degree               Product Designer
# 40     34  Female  Master's Degree                    UX Designer
# 51     33    Male  Master's Degree  Business Intelligence Analyst
# ...   ...     ...              ...                            ...
# 6230   33  Female  Master's Degree              Marketing Manager
# 6244   33  Female  Master's Degree              Marketing Manager
# 6264   33    Male  Master's Degree      Content Marketing Manager
# 6298   32    Male  Master's Degree      Content Marketing Manager
# 6334   33  Female  Master's Degree      Content Marketing Manager
#
#       Years of Experience    Salary
# 16                    7.0   90000.0
# 20                    5.0   80000.0
# 29                    6.0   90000.0
# ...

# %% [markdown]
# Number of People Aged between 36 to 40 with Master's Degree as their Highest Qualification

# %%
Age_M3 = salaries[(salaries['Age'] >= 36) & (salaries['Age'] <= 40) & (salaries["Education Level"] == "Master's Degree")]

# %%
Age_M3
# Out:
#       Age  Gender  Education Level                   Job Title  \
# 13     40  Female  Master's Degree             Project Manager
# 26     37  Female  Master's Degree            Software Manager
# 65     38  Female  Master's Degree   Digital Marketing Manager
# 98     38  Female  Master's Degree    Public Relations Manager
# 104    39  Female  Master's Degree  Senior Project Coordinator
# ...   ...     ...              ...                         ...
# 6291   39  Female  Master's Degree       Director of Marketing
# 6322   38    Male  Master's Degree       Director of Marketing
# 6347   38    Male  Master's Degree       Director of Marketing
# 6454   37    Male  Master's Degree           Marketing Manager
# 6578   38    Male  Master's Degree           Marketing Manager
#
#       Years of Experience    Salary
# 13                   14.0  130000.0
# 26                   11.0  110000.0
# 65                   10.0   90000.0
# 98                   10.0   90000.0
# ...

# %% [markdown]
# No of people between 41 and 45 with Master's Degree as their Highest Degree

# %%
Age_M4= salaries[(salaries['Age'] >= 41) & (salaries['Age'] <= 45) & (salaries["Education Level"] == "Master's Degree")]

# %%
Age_M4
# Out:
#       Age  Gender  Education Level                  Job Title  \
# 6      42  Female  Master's Degree            Product Manager
# 24     41    Male  Master's Degree          Financial Manager
# 37     42    Male  Master's Degree           Project Engineer
# 44     41    Male  Master's Degree        Strategy Consultant
# 47     45  Female  Master's Degree      Director of Marketing
# ...   ...     ...              ...                        ...
# 6635   43  Female  Master's Degree              Sales Manager
# 6649   43  Female  Master's Degree  Digital Marketing Manager
# 6663   43  Female  Master's Degree              Sales Manager
# 6677   43  Female  Master's Degree  Digital Marketing Manager
# 6691   43  Female  Master's Degree              Sales Manager
#
#       Years of Experience    Salary
# 6                    12.0  120000.0
# 24                   13.0  140000.0
# 37                   14.0  115000.0
# 44                   13.0  130000.0
# ...

# %% [markdown]
# People aged above 46 with Master's Degree as their Highest Degree

# %%
Age_M5 = salaries[(salaries['Age'] >= 46) & (salaries["Education Level"] == "Master's Degree")]

# %%
Age_M5
# Out:
#       Age  Gender  Education Level                         Job Title  \
# 4      52    Male  Master's Degree                          Director
# 21     47    Male  Master's Degree                  VP of Operations
# 41     48    Male  Master's Degree               Operations Director
# 53     47    Male  Master's Degree                     VP of Finance
# 60     51  Female  Master's Degree            Director of Operations
# ...   ...     ...              ...                               ...
# 6672   46    Male  Master's Degree                 Marketing Manager
# 6681   51  Female  Master's Degree         Content Marketing Manager
# 6686   46    Male  Master's Degree             Director of Marketing
# 6695   51  Female  Master's Degree  Senior Product Marketing Manager
# 6700   46    Male  Master's Degree                 Marketing Manager
#
#       Years of Experience    Salary
# 4                    20.0  200000.0
# 21                   19.0  190000.0
# ...

# %%
# Creating a Dataset
Ma_Age = ["20-25 years", "26-30 years", "31-35 years", "36-40 years", "41-45 years", "46 years and above"]
Ma_List = [(len(Age_M.index)),(len(Age_M1.index)),(len(Age_M2.index)),(len(Age_M3.index)),(len(Age_M4.index)),(len(Age_M5.index))]

# Creating a plot
fig = plt.figure()
plt.pie(Ma_List, labels = Ma_Age)
# Out:
# ([<matplotlib.patches.Wedge at 0x16a05cd6650>,
# ...
#  [Text(1.0945426585731908, 0.10943659608892994, '20-25 years'),
#   Text(0.6747848487595842, 0.868714802385976, '26-30 years'),
#   Text(-0.9724028805234944, 0.5142301410357146, '31-35 years'),
#   Text(-0.4320834043919519, -1.0115848613186444, '36-40 years'),
#   Text(0.6994471549776847, -0.8489839087954629, '41-45 years'),
#   Text(1.0771074224466617, -0.22324784547741727, '46 years and above')])

# %% [markdown]
# People aged between 20 and 25 with PhD as their Highest Degree

# %%
Age_P = salaries[(salaries['Age'] >= 20) & (salaries['Age'] <= 25) & (salaries["Education Level"] == "PhD")]

# %%
Age_P
# Out:
#       Age Gender Education Level                  Job Title  \
# 2374   25   Male             PhD  Software Engineer Manager
# 2412   23   Male             PhD  Software Engineer Manager
# 2454   25   Male             PhD  Software Engineer Manager
# 2492   23   Male             PhD  Software Engineer Manager
# 2560   24   Male             PhD  Software Engineer Manager
# 2583   23   Male             PhD  Software Engineer Manager
# 2652   23   Male             PhD  Software Engineer Manager
# 2806   24   Male             PhD  Software Engineer Manager
# 2829   23   Male             PhD  Software Engineer Manager
# 2854   23   Male             PhD  Software Engineer Manager
# 2879   23   Male             PhD  Software Engineer Manager
# 2925   24   Male             PhD  Software Engineer Manager
# 2948   23   Male             PhD  Software Engineer Manager
# 2973   23   Male             PhD  Software Engineer Manager
# 2998   23   Male             PhD  Software Engineer Manager
# ...

# %% [markdown]
# People aged between 26 and 30 with PhD as their Highest Degree

# %%
Age_P1 = salaries[(salaries['Age'] >= 26) & (salaries['Age'] <= 30) & (salaries["Education Level"] == "PhD")]

# %%
Age_P1
# Out:
#       Age  Gender Education Level             Job Title  Years of Experience  \
# 377    30    Male             PhD        Data Scientist                  5.0
# 385    27    Male             PhD        Data Scientist                  2.0
# 396    30  Female             PhD        Data Scientist                  5.0
# 404    27    Male             PhD        Data Scientist                  2.0
# 415    30  Female             PhD        Data Scientist                  5.0
# ...   ...     ...             ...                   ...                  ...
# 6638   28    Male             PhD  Sales Representative                  4.0
# 6652   28    Male             PhD     Marketing Manager                  4.0
# 6666   28    Male             PhD  Sales Representative                  4.0
# 6680   28    Male             PhD     Marketing Manager                  4.0
# 6694   28    Male             PhD  Sales Representative                  4.0
#
#         Salary
# 377   180000.0
# ...

# %% [markdown]
# People Aged Between 31 and 35 with PhD as their Highest Degree

# %%
Age_P2 = salaries[(salaries['Age'] >= 31) & (salaries['Age'] <= 35) & (salaries["Education Level"] == "PhD")]

# %%
Age_P2
# Out:
#       Age  Gender Education Level                         Job Title  \
# 381    33    Male             PhD                    Data Scientist
# 389    33    Male             PhD                    Data Scientist
# 400    33    Male             PhD                    Data Scientist
# 408    33    Male             PhD                    Data Scientist
# 419    33    Male             PhD                    Data Scientist
# ...   ...     ...             ...                               ...
# 6523   35  Female             PhD  Senior Product Marketing Manager
# 6537   35  Female             PhD  Senior Product Marketing Manager
# 6551   35  Female             PhD  Senior Product Marketing Manager
# 6565   35  Female             PhD  Senior Product Marketing Manager
# 6586   32    Male             PhD  Senior Product Marketing Manager
#
#       Years of Experience    Salary
# 381                   8.0  190000.0
# 389                   8.0  190000.0
# 400                   8.0  190000.0
# ...

# %% [markdown]
# No of people Aged Between 36 and 40 with PhD as their Highest Degree

# %%
Age_P3 = salaries[(salaries['Age'] >= 36) & (salaries['Age'] <= 40) & (salaries["Education Level"] == "PhD")]

# %%
Age_P3
# Out:
#       Age  Gender Education Level                         Job Title  \
# 9      38    Male             PhD                  Senior Scientist
# 17     39    Male             PhD                   Senior Engineer
# 48     38    Male             PhD                  Senior Scientist
# 90     36    Male             PhD               Principal Scientist
# 1101   37    Male             PhD                   Product Manager
# ...   ...     ...             ...                               ...
# 6633   36  Female             PhD                 Marketing Manager
# 6647   36  Female             PhD  Senior Product Marketing Manager
# 6661   36  Female             PhD                 Marketing Manager
# 6675   36  Female             PhD  Senior Product Marketing Manager
# 6689   36  Female             PhD                 Marketing Manager
#
#       Years of Experience    Salary
# 9                    10.0  110000.0
# 17                   12.0  115000.0
# 48                   11.0  120000.0
# ...

# %% [markdown]
# No of People aged between 41 and 45 with PhD as their Highest Degree

# %%
Age_P4 = salaries[(salaries['Age'] >= 41) & (salaries['Age'] <= 45) & (salaries["Education Level"] == "PhD")]

# %%
Age_P4
# Out:
#       Age  Gender Education Level                  Job Title  \
# 2      45    Male             PhD             Senior Manager
# 28     43  Female             PhD          Senior Consultant
# 57     43    Male             PhD            Senior Engineer
# 72     45    Male             PhD          Research Director
# 105    44    Male             PhD         Chief Data Officer
# ...   ...     ...             ...                        ...
# 4576   42    Male             PhD             Director of HR
# 4628   42    Male             PhD             Director of HR
# 6305   45  Female             PhD          Financial Manager
# 6456   42    Male             PhD  Content Marketing Manager
# 6580   43    Male             PhD  Content Marketing Manager
#
#       Years of Experience    Salary
# 2                    15.0  150000.0
# 28                   15.0  140000.0
# 57                   17.0  140000.0
# 72                   16.0  190000.0
# 105                  16.0  220000.0
# ...

# %% [markdown]
# No of People Aged above 45 with PhD Degrees as their Highest Degree

# %%
Age_P5 = salaries[(salaries['Age'] >= 46) & (salaries["Education Level"] == "PhD")]

# %%
Age_P5
# Out:
#       Age  Gender Education Level                         Job Title  \
# 34     46    Male             PhD                    Senior Manager
# 63     47    Male             PhD             Senior Data Scientist
# 83     52    Male             PhD          Chief Technology Officer
# 96     47    Male             PhD                Research Scientist
# 117    48    Male             PhD                Principal Engineer
# ...   ...     ...             ...                               ...
# 6641   49  Female             PhD             Director of Marketing
# 6655   49  Female             PhD  Senior Product Marketing Manager
# 6669   49  Female             PhD             Director of Marketing
# 6683   49  Female             PhD  Senior Product Marketing Manager
# 6697   49  Female             PhD             Director of Marketing
#
#       Years of Experience    Salary
# 34                   20.0  170000.0
# 63                   21.0  180000.0
# 83                   24.0  250000.0
# ...

# %%
# Creating a Dataset
PhD_Age = ["20-25 years", "26-30 years", "31-35 years", "36-40 years", "41-45 years", "46 years and above"]
PhD_List = [(len(Age_P.index)),(len(Age_P1.index)),(len(Age_P2.index)),(len(Age_P3.index)),(len(Age_P4.index)),(len(Age_P5.index))]

# Creating a plot
fig = plt.figure()
plt.pie(PhD_List, labels = PhD_Age)
# Out:
# ([<matplotlib.patches.Wedge at 0x16a09a7d450>,
# ...
#  [Text(1.0990617062825254, 0.04542428627225738, '20-25 years'),
#   Text(1.0275853934886414, 0.3925152979041635, '26-30 years'),
#   Text(0.3747721833486433, 1.0341884792377505, '31-35 years'),
#   Text(-0.6561243030638229, 0.8828934810774247, '36-40 years'),
#   Text(-1.0413015445337768, -0.35452939702029107, '41-45 years'),
#   Text(0.6107336216918339, -0.9148794692937294, '46 years and above')])

# %% [markdown]
# Finally, when we take a look at our comparison between age and Educational level, we see that similarly to our last comparison between Years of Experience and Educational Level, Most of the younger demographics have the lower qualifications as their highest form of education. We see that most Barchelor degree holders in the company are aged between 20 and 35 (about 85.77%) and which is true also for those who are high school degree holders (97.7%). However for the PhD and Master's Degree holders we see that 71.37% and 41.27% of their respective holders are above 35 years.

# %%
sns.pairplot(salaries)

# %% [markdown]
# Finally, we see that Salary tend to increase across the age groups and by how long you stay at the company when we look at the average Salary by Age and average Salary by Years of Experience. And
